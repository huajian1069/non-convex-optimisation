# %%
from library.optimiser import *
from library.objective_function import *
from library.post_analysis import *
# %matplotlib notebook

# %%
ad = adam()
ak_1d = ackley(dim=1) 
x0 = torch.tensor([52.34232], requires_grad=True)
optmizerParas = {
         'x0': x0,
         'alpha': 0.8,
         'beta_1': 0.9, 
         'beta_2': 0.999, 
         'epsilon': 1e-11, 
         'max_iter': 200,
         'tol': 1e-3,              
         'verbose': True,
         'record': True }
ad.set_parameters(optmizerParas)
arg, val, stats = ad.optimise(ak_1d)
# Out:
# *******starting optimisation from intitial point:  52.34232
# total evaluatios = 173
# gradient at stop position = tensor([0.5116]),
# modified graident = tensor([0.0012])
# found minimum position = [-0.9641911], found minimum = 3.5753488540649414

# %%
stats['func'] = ak_1d
post = post_analy1d(stats)
post.plot_position_after_before()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
post = post_analy1d(stats)
post.plot_grandient_before_after()
# Out:
# <img src="data:image/png;base64,..." width="800">
